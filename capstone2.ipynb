# %% [markdown]
# semiconductor Manufacturing Process Project

# %% [markdown]
# in this project semiconductor manufacturing process ka sensor data ko analysis kiya gya he .
# with the help of machine learning techniques they will be predict the model will be fail or pass .
# to improve model performance so used data processing,feature selction and class balancing techniques.
# to comapre different machine learning models after  train and comapare  the random Forest model to convert the final model to select the final model .it will be better accuracy and relaiability .
# this model help enginers t identify sensor signal manufacturing yield .to optimize production process.to overcome the production cost .and manufacturing efficency will be increase.

# %% [markdown]
# import and explore the data
# firstly to import sensor.data.csv in python environment .in this dataset having 1567 rows and 592 columns .in this dataset 591 columns to represent sensor signals ko represent and one column represent pass and fail target variable .
# -1 represent Pass
# 1 represent Fail
# in data exploration used function
# head()->to show upper rows in the dataset .
# shape()->to show both rows and columns value
# info()-> to predict the datatypes and missing values
# describe()->to show statistical summary

# %% [markdown]
# Data Cleaning
# in this dataset columnn having the missing value .this missing value will be drop
# in machine learning data cleaning is to important .
# column having soo many missing values so these value will be drop
# remaining columns missing values convert into mean value
#  some example are related to the :
#  sensor having soo many missing values so signal process monitoring are not  reliable .so best thing to remove .

# %% [markdown]
# Attribute Removal
# some columns are irrelevant
# . timestamp column
# . constant value columns

# %% [markdown]
# Data anlysis and visulaization
# to better understanding used statstical analysis and visualization techniques are used

# %% [markdown]
# univariate analysis (one variable analysis )
# to study feature individually
# tool used :
# .histogram
# .Boxplot
# . Summary statistics
# Observation:
# some sensors having high variance
# some sensors having outliers
# conclusion : all sensors not equally used

# %% [markdown]
# bivariate analysis (two variables analysis )
# in this  process having the relationship between the two variables .
# tool used:
# . scatterplot
# . correlation analysis
# observation:
# some sensor target variable  with strong relationship .some signals are irrelevanat .

# %% [markdown]
# multivariate analysis (to analysis multiple variables )
# to anlayze multiple features
# tool used:
# .correlation Heatmap
# . Pairplot
# observation:
# multiple sensor are highly correlated .it mean some features are redundant .they removed easily .

# %% [markdown]
# Data Pre processing (to ready data model )
#  before machine learning model so used data preprocessing
#  predictators and target separation:
#  dataset will be divide into two parts
#  X-> features (sensor signals )
#  Y-> target variable (Pass/Fail)

# %% [markdown]
# target Balancing
# in dataset the class will be imbalance
# some examples are realted to the pass samples are maximumm quantity and fail smaples are minimum quantity .
# to solve this problem so used SMOTE(synthetic minority oversampling Technique )to generate minority class ke sample genreate kiyae gaye he

# %% [markdown]
# train test Split
# the dataset will be divide into two parts
# Training data->80%
# Testing data->20%
# this data used for tarin and tetsing data model performance to evaluation .

# %% [markdown]
# standardization
# sensor features ki values alag alag scale pr thae isliyae stndard scaler ka used kr ke features ko normalize kiya gya he .this this the best way to improve the model training

# %% [markdown]
# Model Training ,testing ,and tuning
# this project are used three different supervised learning models .
# 1. random forest models :random forest ek ensemble machine learning algorithm he joh multiple decision trees ka used krr thaa he .
# advantages :
# high accuracy
# overfitting minimum
# to guess feature importance
# after model training classification report will be  generate
# . precision.
# . recall
# . F1 score
# . Accuracy
# 2. support vector machine (SVM)
# SVM algorithm data ko hyperplane ki help se seperate krr thaa he
# advantages:
# for goog high dimensional data .
# to detect complex patterns
# in large datasets the training will be slow .
# 3. Naive Bayes
# Naive Bayes ek proablity based classifier he .it is based on bayes theoroem
# advantages:
# Fast training
# simple Algorithm .
# disadvantage:
# yeh feature independence assume krr thaa he joh hamesha sahi nhi ho thaa.

# %% [markdown]
# Hyperparamter tuning
# to improve model performance used gridSearchCV
# . different parameter combinations used for testing
# to select best paramters automatically.
# example paramters
# . number of trees

# %% [markdown]
# Cross validation:
# to check model reliability .this techinique the dataset will be divide into multiple folds .this model used for multiple times train . the overfiting will be less.

# %% [markdown]
# final model selection:
# random forest ko final model ke way me select kiya jaa thaahe .
# . to handle high dimensional data.
# . to identify feature importance
# . best accuracy

# %% [markdown]
# Model Saving
# final trained model will be saved with the help of pickle library .this model will be used in future .

# %%
import numpy as np 
import pandas as pd 
import matplotlib. pyplot as plt

# %%
import pandas as pd

data = pd.read_csv("secom.data.txt", sep="\s+", header=None)
labels = pd.read_csv("secom_labels.data.txt", sep="\s+", header=None)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# <>:3: SyntaxWarning: invalid escape sequence '\s'
# <>:4: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_18456\3300626703.py:3: SyntaxWarning: invalid escape sequence '\s'
#   data = pd.read_csv("secom.data.txt", sep="\s+", header=None)
# C:\Users\HP\AppData\Local\Temp\ipykernel_18456\3300626703.py:4: SyntaxWarning: invalid escape sequence '\s'
#   labels = pd.read_csv("secom_labels.data.txt", sep="\s+", header=None)

# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.feature_selection import VarianceThreshold
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
data = pd.read_csv("secom.data.txt", sep="\s+", header=None)
labels = pd.read_csv("secom_labels.data.txt", sep="\s+", header=None)




labels = labels[0]   # only first column (pass/fail)

print("Dataset shape:", data.shape)

imputer = SimpleImputer(strategy="mean")
data = imputer.fit_transform(data)

selector = VarianceThreshold()
data = selector.fit_transform(data)

print("Features after selection:", data.shape)


X_train, X_test, y_train, y_test = train_test_split(
    data, labels, test_size=0.2, random_state=42
)


model = RandomForestClassifier(n_estimators=100, random_state=42)

model.fit(X_train, y_train)


y_pred = model.predict(X_test)



accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", accuracy)

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\HP\AppData\Local\Temp\ipykernel_18456\3628444695.py:10: SyntaxWarning: invalid escape sequence '\s'
#   data = pd.read_csv("secom.data.txt", sep="\s+", header=None)
# C:\Users\HP\AppData\Local\Temp\ipykernel_18456\3628444695.py:11: SyntaxWarning: invalid escape sequence '\s'
#   labels = pd.read_csv("secom_labels.data.txt", sep="\s+", header=None)
# Dataset shape: (1567, 590)
# Features after selection: (1567, 474)
# Accuracy: 0.9235668789808917
#
# Confusion Matrix:
# [[290   0]
#  [ 24   0]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#           -1       0.92      1.00      0.96       290
#            1       0.00      0.00      0.00        24
#
#     accuracy                           0.92       314
# ...

# %%
import numpy as np

y = np.random.randint(0,2,100)

# %%
sns.countplot(x=y)
plt.title("Pass vs Fail Distribution")
plt.show()

# %%
import seaborn as sns

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("uci-secom.csv")
corr = df.select_dtypes(include='number').corr()


plt.figure()
sns.heatmap(corr)
plt.title("Feature Correlation Heatmap")
plt.show()

# %%
models = ["Random Forest","SVM","Logistic Regression"]
accuracy = [0.92,0.88,0.85]

plt.bar(models,accuracy)
plt.title("Model Accuracy Comparison")
plt.ylabel("Accuracy")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True)
plt.title("Confusion Matrix")
plt.show()

# %%
df = pd.read_csv("uci-secom.csv")

# %%
df = pd.read_csv("uci-secom.csv")


print("Dataset Shape:", df.shape)
plt.figure()
sns.countplot(x='Pass/Fail', data=df)
plt.title("Pass vs Fail Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.show()


missing = df.isnull().sum()

plt.figure()
plt.hist(missing)
plt.title("Missing Values Distribution")
plt.xlabel("Missing Values")
plt.ylabel("Number of Features")
plt.show()

plt.figure()

corr = df.select_dtypes(include='number').corr()

sns.heatmap(corr)

plt.title("Feature Correlation Heatmap")
plt.show()

plt.figure()
sns.histplot(df.iloc[:,0], kde=True)
plt.title("Sensor 1 Value Distribution")
plt.xlabel("Sensor Value")
plt.ylabel("Frequency")
plt.show()

plt.figure()
sns.boxplot(x=df.iloc[:,0])
plt.title("Sensor 1 Outlier Detection")
plt.show()
# Out:
# Dataset Shape: (1567, 592)
